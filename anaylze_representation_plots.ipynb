# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
d2v_mimic = pd.read_csv("results/representation_plots/d2v_mimic.csv")
plt.rcParams["figure.figsize"] = (14,6)
p = sns.scatterplot(x=d2v_mimic.x, y=d2v_mimic.y, hue=d2v_mimic.label, s=60)
plt.legend(loc=(0,1.05), ncol=2, frameon=False)
p.set_ylabel("y", fontsize=22)
p.set_xlabel("x", fontsize=22)
p.tick_params(labelsize=18)
p.tick_params(labelsize=13)
plt.setp(p.get_legend().get_title(), fontsize=22)
plt.setp(p.get_legend().get_texts(), fontsize=22)
# Out:
# [None, None, None, None, None, None]

# %%
d2v_uci = pd.read_csv("results/representation_plots/d2v_uci.csv")
plt.rcParams["figure.figsize"] = (14,6)
p = sns.scatterplot(x=d2v_uci.x, y=d2v_uci.y, hue=d2v_uci.label, s=60)
plt.legend(loc=(0,1.05), ncol=4, frameon=False)
p.set_ylabel("y", fontsize=22)
p.set_xlabel("x", fontsize=22)
p.tick_params(labelsize=18)
p.tick_params(labelsize=13)
plt.setp(p.get_legend().get_title(), fontsize=22)
plt.setp(p.get_legend().get_texts(), fontsize=22)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
liltab_uci = pd.read_csv("results/representation_plots/liltab_uci.csv")
plt.rcParams["figure.figsize"] = (14,6)
p = sns.scatterplot(x=liltab_uci.x, y=liltab_uci.y, hue=liltab_uci.label, s=60)
plt.legend(loc=(0,1.05), ncol=4, frameon=False)
p.set_ylabel("y", fontsize=22)
p.set_xlabel("x", fontsize=22)
p.tick_params(labelsize=18)
p.tick_params(labelsize=13)
plt.setp(p.get_legend().get_title(), fontsize=22)
plt.setp(p.get_legend().get_texts(), fontsize=22)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
liltab_mimic = pd.read_csv("results/representation_plots/liltab_mimic.csv")
plt.rcParams["figure.figsize"] = (14,6)
p = sns.scatterplot(x=liltab_mimic.x, y=liltab_mimic.y, hue=liltab_mimic.label, s=60)
plt.legend(loc=(0,1.05), ncol=2, frameon=False)
p.set_ylabel("y", fontsize=22)
p.set_xlabel("x", fontsize=22)
p.tick_params(labelsize=18)
p.tick_params(labelsize=13)
plt.setp(p.get_legend().get_title(), fontsize=22)
plt.setp(p.get_legend().get_texts(), fontsize=22)
# Out:
# [None, None, None, None, None, None]
